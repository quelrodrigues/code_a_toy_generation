# %% [markdown]
# <a href="https://colab.research.google.com/github/quelrodrigues/code_a_toy_generation/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno = "Raquel"
idade = 27
altura = 1.65

print(aluno)
print(idade)
print(altura)
# Out:
# Raquel
# 27
# 1.65

# %%
list_professores = ["Felipe", "Marcelo","Luyz"]

print(f"Os professores de 2025 são: {list_professores}")
print(f"Em 2026, temos um novo professor e a lista vai ficar: ")
novo_professor = input('informe o nome do novo professor: ')

#para adicionar um novo valor, fazemos:
#chamar a lista e colocar o atributo append com o novo valor
#list.append("novo valor")
list_professores.append(novo_professor)
print(list_professores)

#agora vamos remover um dos valores
#para remover usamos a ferramenta pop
#chamar a lista e colocar o atributo pop, com a posição
#valor que queremos remover
#list.pop(index)
list_professores.pop(1)
print(list_professores)
# Out:
# Os professores de 2025 são: ['Felipe', 'Marcelo', 'Luyz']
# Em 2026, temos um novo professor e a lista vai ficar:
# informe o nome do novo professor: André
# ['Felipe', 'Marcelo', 'Luyz', 'André']
# ['Felipe', 'Luyz', 'André']

# %%
import random
#quando colocamos import random, o sistema aprende a
#sortear valores

list_dado = [1,2,3,4,5,6]

sortear = random.choice(list_dado)
print(sortear)
# Out:
# 1

# %%
#JOGO 1 - Remover valor da lista
#temos a lista
#Desafio de vocês
#1 - sortear uma posição da lista dos pets
#2 - usando o comando pop, remover  a posição sorteada
#boa sorte :)

import random
list_pets = ["Meg","Duda","Pandora","Joy","Garoa","Mini","Soneca","Honda","Lucky","Bingo"]
print(list_pets)
sorteio = random.choice(list_pets)
print(sorteio)
print(f"A lista tem os elementos: {list_pets}")
posicao = int(input('Informe a posição do valor sorteado '))
print(f"o valor removido foi {list_pets[posicao]}")
list_pets.pop(posicao)
print(list_pets)
# Out:
# ['Meg', 'Duda', 'Pandora', 'Joy', 'Garoa', 'Mini', 'Soneca', 'Honda', 'Lucky', 'Bingo']
# Honda
# A lista tem os elementos: ['Meg', 'Duda', 'Pandora', 'Joy', 'Garoa', 'Mini', 'Soneca', 'Honda', 'Lucky', 'Bingo']
# Informe a posição do valor sorteado 1
# o valor removido foi Duda
# ['Meg', 'Pandora', 'Joy', 'Garoa', 'Mini', 'Soneca', 'Honda', 'Lucky', 'Bingo']
